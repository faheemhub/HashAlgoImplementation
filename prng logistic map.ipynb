# %%
import numpy as np

# %%
def logisticmap(x_init, r, length):
    x = [r*x_init*(1-x_init)]
    for t in range(length):
       x.append(r*x[-1]*(1-x[-1]))
    return np.array(x)
x = logisticmap(0.2, 3.92, 250000)

# %%
x
# Out:
# array([0.6272    , 0.91657503, 0.29974377, ..., 0.97808252, 0.08403345,
#        0.30172959])
